# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
       cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb9e41b9c95443d8029d9e00c928ead

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description)
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | urumqi
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | jiangyou
# Processing Record 5 of Set 1 | shellbrook
# Processing Record 6 of Set 1 | olafsvik
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | tucurui
# Processing Record 9 of Set 1 | corpus christi
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | vardo
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | taltal
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | sunrise manor
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | mon
# Processing Record 22 of Set 1 | karratha
# Processing Record 23 of Set 1 | nome
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | nabire
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | port hawkesbury
# Processing Record 30 of Set 1 | ocampo
# Processing Record 31 of Set 1 | ola
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | oistins
# Processing Record 34 of Set 1 | byron bay
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | sambava
# Processing Record 38 of Set 1 | suntar
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | salym
# Processing Record 44 of Set 1 | kargasok
# Processing Record 45 of Set 1 | san ignacio
# Processing Record 46 of Set 1 | ulladulla
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | tiarei
# Processing Record 50 of Set 1 | wittlich
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | troitskoye
# Processing Record 3 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 2 | namibe
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | zwedru
# Processing Record 8 of Set 2 | mount isa
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | jacareacanga
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | wukari
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | puerto del rosario
# Processing Record 15 of Set 2 | atar
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | antalaha
# Processing Record 18 of Set 2 | tanglad
# Processing Record 19 of Set 2 | kapchorwa
# Processing Record 20 of Set 2 | muskegon
# Processing Record 21 of Set 2 | leningradskiy
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | aljezur
# Processing Record 24 of Set 2 | hammerfest
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | tocantinopolis
# City not found. Skipping...
# Processing Record 27 of Set 2 | palmer
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | porgera
# Processing Record 32 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | quelimane
# Processing Record 35 of Set 2 | villa carlos paz
# Processing Record 36 of Set 2 | oktyabrskiy
# Processing Record 37 of Set 2 | zheleznodorozhnyy
# Processing Record 38 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | mount gambier
# Processing Record 41 of Set 2 | ust-nera
# Processing Record 42 of Set 2 | linjiang
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | dalbandin
# Processing Record 45 of Set 2 | korla
# Processing Record 46 of Set 2 | aberdeen
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | khani
# Processing Record 49 of Set 2 | setermoen
# Processing Record 50 of Set 2 | voskresenskoye
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | harper
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | itarema
# Processing Record 8 of Set 3 | planadas
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | taksimo
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | muravlenko
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | isangel
# Processing Record 16 of Set 3 | rio grande
# Processing Record 17 of Set 3 | the valley
# Processing Record 18 of Set 3 | balkhash
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | muisne
# Processing Record 21 of Set 3 | amla
# Processing Record 22 of Set 3 | salinopolis
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | busselton
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | callaway
# Processing Record 27 of Set 3 | porto santo
# Processing Record 28 of Set 3 | aksay
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | iralaya
# Processing Record 32 of Set 3 | mlimba
# Processing Record 33 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 34 of Set 3 | khyriv
# Processing Record 35 of Set 3 | acapulco
# Processing Record 36 of Set 3 | hirara
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | valente
# Processing Record 39 of Set 3 | okhotsk
# Processing Record 40 of Set 3 | store heddinge
# Processing Record 41 of Set 3 | olot
# Processing Record 42 of Set 3 | qeshm
# Processing Record 43 of Set 3 | pytalovo
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | jalingo
# Processing Record 46 of Set 3 | mount pleasant
# Processing Record 47 of Set 3 | moorhead
# Processing Record 48 of Set 3 | juneau
# Processing Record 49 of Set 3 | vestmannaeyjar
# Processing Record 50 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | alyangula
# Processing Record 3 of Set 4 | cedar city
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | abbeville
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | te anau
# Processing Record 8 of Set 4 | were ilu
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 4 | half moon bay
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | kaka
# Processing Record 14 of Set 4 | ocos
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | kassala
# Processing Record 17 of Set 4 | cabanas
# Processing Record 18 of Set 4 | lasa
# Processing Record 19 of Set 4 | ihosy
# Processing Record 20 of Set 4 | codrington
# Processing Record 21 of Set 4 | el reno
# Processing Record 22 of Set 4 | bathsheba
# Processing Record 23 of Set 4 | san policarpo
# Processing Record 24 of Set 4 | paita
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | yate
# Processing Record 27 of Set 4 | gornozavodsk
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | kaeo
# Processing Record 30 of Set 4 | quzhou
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | walvis bay
# Processing Record 35 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 4 | huilong
# Processing Record 37 of Set 4 | lhokseumawe
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | tessalit
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 4 | houma
# Processing Record 43 of Set 4 | constitucion
# Processing Record 44 of Set 4 | pischia
# Processing Record 45 of Set 4 | keetmanshoop
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | faanui
# Processing Record 50 of Set 4 | beloha
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | luancheng
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | doctor juan leon mallorquin
# Processing Record 6 of Set 5 | nexo
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | broome
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | matamoros
# Processing Record 11 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | amalapuram
# Processing Record 14 of Set 5 | russell
# Processing Record 15 of Set 5 | murdochville
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | saryg-sep
# Processing Record 18 of Set 5 | jalu
# Processing Record 19 of Set 5 | norsup
# Processing Record 20 of Set 5 | muros
# Processing Record 21 of Set 5 | ossora
# Processing Record 22 of Set 5 | raga
# Processing Record 23 of Set 5 | yelan
# Processing Record 24 of Set 5 | ushibuka
# Processing Record 25 of Set 5 | atambua
# Processing Record 26 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 5 | saint-francois
# Processing Record 28 of Set 5 | hilpoltstein
# Processing Record 29 of Set 5 | carambei
# Processing Record 30 of Set 5 | vila franca do campo
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 5 | parry sound
# Processing Record 34 of Set 5 | kavaratti
# Processing Record 35 of Set 5 | camapua
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | labuhan
# Processing Record 39 of Set 5 | bud
# Processing Record 40 of Set 5 | labrea
# Processing Record 41 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 42 of Set 5 | lugovoy
# Processing Record 43 of Set 5 | upata
# Processing Record 44 of Set 5 | sakakah
# Processing Record 45 of Set 5 | yinchuan
# Processing Record 46 of Set 5 | granada
# Processing Record 47 of Set 5 | vaasa
# Processing Record 48 of Set 5 | burnie
# Processing Record 49 of Set 5 | mtimbira
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | christchurch
# Processing Record 2 of Set 6 | waipawa
# Processing Record 3 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 5 of Set 6 | el retorno
# Processing Record 6 of Set 6 | ban dung
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | taitung
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | batagay-alyta
# Processing Record 11 of Set 6 | pouembout
# Processing Record 12 of Set 6 | ixtapa
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | gawler
# Processing Record 15 of Set 6 | baykit
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | bambous virieux
# Processing Record 18 of Set 6 | hobyo
# Processing Record 19 of Set 6 | arkhangelskoye
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | london
# Processing Record 22 of Set 6 | atherton
# Processing Record 23 of Set 6 | saint anthony
# Processing Record 24 of Set 6 | marsabit
# Processing Record 25 of Set 6 | ducheng
# Processing Record 26 of Set 6 | tautira
# Processing Record 27 of Set 6 | radovitskiy
# Processing Record 28 of Set 6 | arman
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | souillac
# Processing Record 31 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | tilichiki
# Processing Record 33 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | humberto de campos
# Processing Record 37 of Set 6 | arrifes
# Processing Record 38 of Set 6 | riyadh
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | khor
# Processing Record 41 of Set 6 | batagay
# Processing Record 42 of Set 6 | xinzhi
# Processing Record 43 of Set 6 | pozo colorado
# Processing Record 44 of Set 6 | tarko-sale
# Processing Record 45 of Set 6 | grosseto
# Processing Record 46 of Set 6 | tacuati
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | kropotkin
# Processing Record 49 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | stuttgart
# Processing Record 2 of Set 7 | erbaa
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | anadyr
# Processing Record 5 of Set 7 | tual
# Processing Record 6 of Set 7 | ayagoz
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | saint george
# Processing Record 9 of Set 7 | bida
# Processing Record 10 of Set 7 | marzuq
# Processing Record 11 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | krabi
# Processing Record 13 of Set 7 | mul
# Processing Record 14 of Set 7 | lebanon
# Processing Record 15 of Set 7 | meadow lake
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | coihaique
# Processing Record 18 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | ambovombe
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | lesosibirsk
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | amol
# Processing Record 25 of Set 7 | monster
# Processing Record 26 of Set 7 | vanavara
# Processing Record 27 of Set 7 | saucillo
# Processing Record 28 of Set 7 | barcelos
# Processing Record 29 of Set 7 | pompeu
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | nanakuli
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | zhuhai
# Processing Record 34 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | goderich
# Processing Record 37 of Set 7 | severo-yeniseyskiy
# Processing Record 38 of Set 7 | mazagao
# Processing Record 39 of Set 7 | baiyin
# Processing Record 40 of Set 7 | casablanca
# Processing Record 41 of Set 7 | high prairie
# Processing Record 42 of Set 7 | inhambane
# Processing Record 43 of Set 7 | northam
# Processing Record 44 of Set 7 | porbandar
# Processing Record 45 of Set 7 | axim
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 49 of Set 7 | port blair
# Processing Record 50 of Set 7 | mackay
# Processing Record 1 of Set 8 | dwarka
# Processing Record 2 of Set 8 | havoysund
# Processing Record 3 of Set 8 | grindavik
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 8 | kaliua
# Processing Record 7 of Set 8 | kurilsk
# Processing Record 8 of Set 8 | kilmez
# City not found. Skipping...
# Processing Record 9 of Set 8 | kununurra
# Processing Record 10 of Set 8 | sitka
# Processing Record 11 of Set 8 | keokuk
# Processing Record 12 of Set 8 | xiantao
# Processing Record 13 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 14 of Set 8 | bandarbeyla
# Processing Record 15 of Set 8 | ponta delgada
# Processing Record 16 of Set 8 | tessaoua
# Processing Record 17 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 18 of Set 8 | touros
# Processing Record 19 of Set 8 | sandnessjoen
# Processing Record 20 of Set 8 | wad rawah
# Processing Record 21 of Set 8 | san-pedro
# Processing Record 22 of Set 8 | rio gallegos
# Processing Record 23 of Set 8 | jishou
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | fare
# Processing Record 26 of Set 8 | akcaabat
# Processing Record 27 of Set 8 | mana
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | devils lake
# Processing Record 30 of Set 8 | waitara
# Processing Record 31 of Set 8 | griffith
# Processing Record 32 of Set 8 | dunda
# Processing Record 33 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 8 | kotma
# Processing Record 35 of Set 8 | longyearbyen
# Processing Record 36 of Set 8 | balakovo
# Processing Record 37 of Set 8 | faya
# Processing Record 38 of Set 8 | mangochi
# Processing Record 39 of Set 8 | wasilla
# Processing Record 40 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 8 | bubaque
# Processing Record 42 of Set 8 | carutapera
# Processing Record 43 of Set 8 | haines junction
# Processing Record 44 of Set 8 | usta muhammad
# Processing Record 45 of Set 8 | pitimbu
# Processing Record 46 of Set 8 | mehamn
# Processing Record 47 of Set 8 | banjar
# Processing Record 48 of Set 8 | mitsamiouli
# Processing Record 49 of Set 8 | ambulu
# Processing Record 50 of Set 8 | oriximina
# Processing Record 1 of Set 9 | colares
# Processing Record 2 of Set 9 | lebrija
# Processing Record 3 of Set 9 | hays
# Processing Record 4 of Set 9 | bogorodskoye
# Processing Record 5 of Set 9 | evensk
# Processing Record 6 of Set 9 | cayenne
# Processing Record 7 of Set 9 | sibsagar
# Processing Record 8 of Set 9 | tuatapere
# Processing Record 9 of Set 9 | talavera
# Processing Record 10 of Set 9 | moron
# Processing Record 11 of Set 9 | tommot
# Processing Record 12 of Set 9 | lebu
# Processing Record 13 of Set 9 | bengkulu
# Processing Record 14 of Set 9 | kruisfontein
# Processing Record 15 of Set 9 | kutum
# Processing Record 16 of Set 9 | saraland
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 9 | rangpur
# Processing Record 20 of Set 9 | airai
# Processing Record 21 of Set 9 | maceio
# Processing Record 22 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 9 | liwale
# Processing Record 24 of Set 9 | noumea
# Processing Record 25 of Set 9 | roebourne
# Processing Record 26 of Set 9 | zarand
# Processing Record 27 of Set 9 | usinsk
# Processing Record 28 of Set 9 | denia
# Processing Record 29 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 30 of Set 9 | vrangel
# Processing Record 31 of Set 9 | sembakung
# Processing Record 32 of Set 9 | cuamba
# Processing Record 33 of Set 9 | port hedland
# Processing Record 34 of Set 9 | hefei
# Processing Record 35 of Set 9 | namatanai
# Processing Record 36 of Set 9 | kodiak
# Processing Record 37 of Set 9 | mango
# Processing Record 38 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 9 | paoua
# Processing Record 40 of Set 9 | aguimes
# Processing Record 41 of Set 9 | mandalgovi
# Processing Record 42 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 9 | komsomolskiy
# Processing Record 44 of Set 9 | snezhnogorsk
# Processing Record 45 of Set 9 | ribeira grande
# Processing Record 46 of Set 9 | gotsu
# Processing Record 47 of Set 9 | ngunguru
# Processing Record 48 of Set 9 | aketi
# Processing Record 49 of Set 9 | paranaiba
# Processing Record 50 of Set 9 | freetown
# Processing Record 1 of Set 10 | strezhevoy
# Processing Record 2 of Set 10 | junagadh
# Processing Record 3 of Set 10 | lebyazhye
# Processing Record 4 of Set 10 | ostrovnoy
# Processing Record 5 of Set 10 | nouadhibou
# Processing Record 6 of Set 10 | ivybridge
# Processing Record 7 of Set 10 | puerto madero
# Processing Record 8 of Set 10 | zirandaro
# Processing Record 9 of Set 10 | west plains
# Processing Record 10 of Set 10 | lompoc
# Processing Record 11 of Set 10 | ternate
# Processing Record 12 of Set 10 | drumheller
# Processing Record 13 of Set 10 | itaituba
# Processing Record 14 of Set 10 | gisborne
# Processing Record 15 of Set 10 | gazojak
# Processing Record 16 of Set 10 | meulaboh
# Processing Record 17 of Set 10 | sainte-suzanne
# Processing Record 18 of Set 10 | saint-gilles
# Processing Record 19 of Set 10 | itanagar
# Processing Record 20 of Set 10 | mayo
# Processing Record 21 of Set 10 | nyurba
# Processing Record 22 of Set 10 | novyy urengoy
# Processing Record 23 of Set 10 | ussuriysk
# Processing Record 24 of Set 10 | kon tum
# Processing Record 25 of Set 10 | kempsey
# Processing Record 26 of Set 10 | miandrivazo
# Processing Record 27 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 10 | raudeberg
# Processing Record 29 of Set 10 | notodden
# Processing Record 30 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | lages
# Processing Record 32 of Set 10 | sestri levante
# Processing Record 33 of Set 10 | ciudad bolivar
# Processing Record 34 of Set 10 | kuytun
# Processing Record 35 of Set 10 | nemuro
# Processing Record 36 of Set 10 | winslow
# Processing Record 37 of Set 10 | nouakchott
# Processing Record 38 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 10 | henties bay
# Processing Record 40 of Set 10 | lerwick
# Processing Record 41 of Set 10 | aswan
# Processing Record 42 of Set 10 | alofi
# Processing Record 43 of Set 10 | boguchany
# Processing Record 44 of Set 10 | north platte
# Processing Record 45 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 46 of Set 10 | inyonga
# Processing Record 47 of Set 10 | khvorostyanka
# Processing Record 48 of Set 10 | kahramanmaras
# Processing Record 49 of Set 10 | luganville
# Processing Record 50 of Set 10 | gimli
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | olupona
# Processing Record 3 of Set 11 | umea
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | hohhot
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | olinda
# Processing Record 8 of Set 11 | abu dhabi
# Processing Record 9 of Set 11 | torbat-e jam
# Processing Record 10 of Set 11 | marawi
# Processing Record 11 of Set 11 | katsuura
# Processing Record 12 of Set 11 | krasnogorskiy
# Processing Record 13 of Set 11 | nishihara
# Processing Record 14 of Set 11 | yelatma
# Processing Record 15 of Set 11 | duz
# City not found. Skipping...
# Processing Record 16 of Set 11 | santa cecilia
# Processing Record 17 of Set 11 | illapel
# Processing Record 18 of Set 11 | bahia blanca
# Processing Record 19 of Set 11 | sarakhs
# Processing Record 20 of Set 11 | nanortalik
# Processing Record 21 of Set 11 | am timan
# Processing Record 22 of Set 11 | belyy yar
# Processing Record 23 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 11 | mattru
# Processing Record 25 of Set 11 | selenduma
# Processing Record 26 of Set 11 | lavrentiya
# Processing Record 27 of Set 11 | talnakh
# Processing Record 28 of Set 11 | ahar
# Processing Record 29 of Set 11 | taoudenni
# Processing Record 30 of Set 11 | bonthe
# Processing Record 31 of Set 11 | bassar
# Processing Record 32 of Set 11 | cangzhou
# Processing Record 33 of Set 11 | kupang
# Processing Record 34 of Set 11 | kalemie
# Processing Record 35 of Set 11 | sarangani
# Processing Record 36 of Set 11 | svetlogorsk
# Processing Record 37 of Set 11 | isiolo
# Processing Record 38 of Set 11 | aklavik
# Processing Record 39 of Set 11 | mindelo
# Processing Record 40 of Set 11 | beya
# Processing Record 41 of Set 11 | lagoa
# Processing Record 42 of Set 11 | mahanoro
# Processing Record 43 of Set 11 | atasu
# Processing Record 44 of Set 11 | saravan
# Processing Record 45 of Set 11 | ewa beach
# Processing Record 46 of Set 11 | shingu
# Processing Record 47 of Set 11 | tres arroyos
# Processing Record 48 of Set 11 | homer
# Processing Record 49 of Set 11 | natal
# Processing Record 50 of Set 11 | poum
# Processing Record 1 of Set 12 | shirvan
# Processing Record 2 of Set 12 | kismayo
# Processing Record 3 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 12 | umba
# Processing Record 5 of Set 12 | norman wells
# Processing Record 6 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 7 of Set 12 | sinjai
# Processing Record 8 of Set 12 | kropachevo
# Processing Record 9 of Set 12 | majene
# Processing Record 10 of Set 12 | ornskoldsvik
# Processing Record 11 of Set 12 | oster
# Processing Record 12 of Set 12 | ust-ordynskiy
# Processing Record 13 of Set 12 | hambantota
# Processing Record 14 of Set 12 | tiznit
# Processing Record 15 of Set 12 | saint-leu
# Processing Record 16 of Set 12 | husavik
# Processing Record 17 of Set 12 | doha
# Processing Record 18 of Set 12 | maroantsetra
# Processing Record 19 of Set 12 | jinxiang
# Processing Record 20 of Set 12 | coos bay
# Processing Record 21 of Set 12 | san lorenzo
# Processing Record 22 of Set 12 | iskateley
# Processing Record 23 of Set 12 | la palma
# Processing Record 24 of Set 12 | cam ranh
# Processing Record 25 of Set 12 | tabou
# Processing Record 26 of Set 12 | takoradi
# Processing Record 27 of Set 12 | cairns
# Processing Record 28 of Set 12 | coahuayana
# Processing Record 29 of Set 12 | beatrice
# Processing Record 30 of Set 12 | swift current
# Processing Record 31 of Set 12 | arenapolis
# Processing Record 32 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 33 of Set 12 | shenzhen
# Processing Record 34 of Set 12 | ulagan
# Processing Record 35 of Set 12 | union
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | linxia
# Processing Record 38 of Set 12 | abu samrah
# Processing Record 39 of Set 12 | boma
# Processing Record 40 of Set 12 | capitao poco
# Processing Record 41 of Set 12 | lakes entrance
# Processing Record 42 of Set 12 | narsaq
# Processing Record 43 of Set 12 | nikki
# Processing Record 44 of Set 12 | umm lajj
# Processing Record 45 of Set 12 | college
# Processing Record 46 of Set 12 | rantepao
# Processing Record 47 of Set 12 | leshukonskoye
# Processing Record 48 of Set 12 | salvador
# Processing Record 49 of Set 12 | yumen
# Processing Record 50 of Set 12 | goundam
# Processing Record 1 of Set 13 | jacqueville
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | almaznyy
# Processing Record 4 of Set 13 | ishigaki
# Processing Record 5 of Set 13 | plettenberg bay
# Processing Record 6 of Set 13 | council bluffs
# Processing Record 7 of Set 13 | ios
# Processing Record 8 of Set 13 | kazanskoye
# Processing Record 9 of Set 13 | perigueux
# Processing Record 10 of Set 13 | mudanjiang
# Processing Record 11 of Set 13 | panalingaan
# Processing Record 12 of Set 13 | aksu
# Processing Record 13 of Set 13 | taveta
# Processing Record 14 of Set 13 | saint-pierre
# Processing Record 15 of Set 13 | masuri
# Processing Record 16 of Set 13 | rawson
# Processing Record 17 of Set 13 | mahajanga
# Processing Record 18 of Set 13 | matsubase
# Processing Record 19 of Set 13 | immokalee
# Processing Record 20 of Set 13 | salalah
# Processing Record 21 of Set 13 | ullapool
# Processing Record 22 of Set 13 | siniscola
# Processing Record 23 of Set 13 | nayoro
# Processing Record 24 of Set 13 | khuzhir
# Processing Record 25 of Set 13 | navalmoral de la mata
# Processing Record 26 of Set 13 | shimoda
# Processing Record 27 of Set 13 | kuhestan
# City not found. Skipping...
# Processing Record 28 of Set 13 | terra santa
# Processing Record 29 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 13 | beipiao
# Processing Record 31 of Set 13 | the pas
# Processing Record 32 of Set 13 | seka
# Processing Record 33 of Set 13 | kalmunai
# Processing Record 34 of Set 13 | staunton
# Processing Record 35 of Set 13 | esfarayen
# Processing Record 36 of Set 13 | tyret pervaya
# Processing Record 37 of Set 13 | jiupu
# Processing Record 38 of Set 13 | morondava
# Processing Record 39 of Set 13 | koslan
# Processing Record 40 of Set 13 | arlit
# Processing Record 41 of Set 13 | gushikawa
# Processing Record 42 of Set 13 | san isidro
# Processing Record 43 of Set 13 | ambilobe
# Processing Record 44 of Set 13 | samarai
# Processing Record 45 of Set 13 | panzhihua
# Processing Record 46 of Set 13 | changji
# Processing Record 47 of Set 13 | hvide sande
# Processing Record 48 of Set 13 | kushima
# Processing Record 49 of Set 13 | antofagasta
# Processing Record 50 of Set 13 | kano
# Processing Record 1 of Set 14 | vaitape
# Processing Record 2 of Set 14 | qaqortoq
# Processing Record 3 of Set 14 | maumere
# Processing Record 4 of Set 14 | camacha
# Processing Record 5 of Set 14 | sao filipe
# Processing Record 6 of Set 14 | erenhot
# Processing Record 7 of Set 14 | sao felix do xingu
# Processing Record 8 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 14 | rongcheng
# Processing Record 10 of Set 14 | niquelandia
# Processing Record 11 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 14 | diffa
# Processing Record 13 of Set 14 | pouebo
# Processing Record 14 of Set 14 | temiscaming
# Processing Record 15 of Set 14 | smirnykh
# Processing Record 16 of Set 14 | srednekolymsk
# Processing Record 17 of Set 14 | borisovka
# Processing Record 18 of Set 14 | ballina
# Processing Record 19 of Set 14 | tomari
# Processing Record 20 of Set 14 | manoel urbano
# Processing Record 21 of Set 14 | luohe
# Processing Record 22 of Set 14 | mecca
# Processing Record 23 of Set 14 | ambanja
# Processing Record 24 of Set 14 | zaltan
# Processing Record 25 of Set 14 | amapa
# Processing Record 26 of Set 14 | galesong
# Processing Record 27 of Set 14 | sinnamary
# Processing Record 28 of Set 14 | eregli
# Processing Record 29 of Set 14 | havelock
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | gamba
# Processing Record 32 of Set 14 | puerto asis
# Processing Record 33 of Set 14 | phanat nikhom
# Processing Record 34 of Set 14 | ahuimanu
# Processing Record 35 of Set 14 | samarinda
# Processing Record 36 of Set 14 | mocuba
# Processing Record 37 of Set 14 | novopokrovka
# Processing Record 38 of Set 14 | luderitz
# Processing Record 39 of Set 14 | chibombo
# Processing Record 40 of Set 14 | eyl
# Processing Record 41 of Set 14 | grand gaube
# Processing Record 42 of Set 14 | merauke
# Processing Record 43 of Set 14 | greystones
# Processing Record 44 of Set 14 | satipo
# Processing Record 45 of Set 14 | launceston
# Processing Record 46 of Set 14 | khandyga
# Processing Record 47 of Set 14 | caucaia
# Processing Record 48 of Set 14 | ampanihy
# Processing Record 49 of Set 14 | san javier
# Processing Record 50 of Set 14 | rosetta
# Processing Record 1 of Set 15 | atagay
# Processing Record 2 of Set 15 | vigrestad
# Processing Record 3 of Set 15 | lorengau
# Processing Record 4 of Set 15 | paamiut
# Processing Record 5 of Set 15 | ponta pora
# Processing Record 6 of Set 15 | menongue
# Processing Record 7 of Set 15 | denpasar
# Processing Record 8 of Set 15 | zonguldak
# Processing Record 9 of Set 15 | dalvik
# Processing Record 10 of Set 15 | bhakkar
# Processing Record 11 of Set 15 | bandundu
# Processing Record 12 of Set 15 | inirida
# Processing Record 13 of Set 15 | almenevo
# City not found. Skipping...
# Processing Record 14 of Set 15 | pulandian
# Processing Record 15 of Set 15 | varadero
# Processing Record 16 of Set 15 | thunder bay
# Processing Record 17 of Set 15 | marang
# Processing Record 18 of Set 15 | port shepstone
# Processing Record 19 of Set 15 | kichmengskiy gorodok
# Processing Record 20 of Set 15 | iracoubo
# Processing Record 21 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 22 of Set 15 | ferrol
# Processing Record 23 of Set 15 | pleszew
# Processing Record 24 of Set 15 | yagodnoye
# Processing Record 25 of Set 15 | green river
# Processing Record 26 of Set 15 | tutoia
# Processing Record 27 of Set 15 | xingtai
# Processing Record 28 of Set 15 | pangai
# Processing Record 29 of Set 15 | san juan
# Processing Record 30 of Set 15 | sechura
# Processing Record 31 of Set 15 | hanzhong
# Processing Record 32 of Set 15 | maragogi
# Processing Record 33 of Set 15 | richards bay
# Processing Record 34 of Set 15 | udachnyy
# Processing Record 35 of Set 15 | maniitsoq
# Processing Record 36 of Set 15 | melur
# Processing Record 37 of Set 15 | hit
# Processing Record 38 of Set 15 | santa maria
# Processing Record 39 of Set 15 | adeje
# Processing Record 40 of Set 15 | ust-maya
# Processing Record 41 of Set 15 | san jose
# Processing Record 42 of Set 15 | barroualie
# City not found. Skipping...
# Processing Record 43 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 44 of Set 15 | paramonga
# Processing Record 45 of Set 15 | sisimiut
# Processing Record 46 of Set 15 | tandil
# Processing Record 47 of Set 15 | keti bandar
# Processing Record 48 of Set 15 | kampot
# Processing Record 49 of Set 15 | horni plana
# Processing Record 50 of Set 15 | igarka
# Processing Record 1 of Set 16 | gori
# Processing Record 2 of Set 16 | sinjar
# Processing Record 3 of Set 16 | villa bruzual
# Processing Record 4 of Set 16 | ambon
# Processing Record 5 of Set 16 | louisbourg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Urumqi  43.8010   87.6005     -6.65        84          39
# 1    Puerto Ayora  -0.7393  -90.3518     73.54        94          65
# 2        Hermanus -34.4187   19.2345     66.27        84          94
# 3        Jiangyou  31.7667  104.7167     38.12        70          92
# 4      Shellbrook  53.2168 -106.4011      4.23        93         100
# 5        Olafsvik  64.8945  -23.7142     25.34        70          68
# 6         Ushuaia -54.8000  -68.3000     40.66        81          75
# 7         Tucurui  -3.7661  -49.6725     73.17        90          94
# 8  Corpus Christi  27.8006  -97.3964     55.63        63          20
# 9         Mataura -46.1927  168.8643     80.40        42          18
#
#    Wind Speed Country Current Description
# 0        2.24      CN                mist
# 1        5.01      EC       broken clouds
# 2        4.32      ZA     overcast clouds
# 3        0.72      CN     overcast clouds
# 4       13.78      CA     overcast clouds
# 5       18.99      IS       broken clouds
# 6       27.63      AR          light rain
# 7        1.52      BR     overcast clouds
# 8        9.22      US          few clouds
# 9        1.52      NZ          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Urumqi      CN  43.8010   87.6005     -6.65        84          39
# 1    Puerto Ayora      EC  -0.7393  -90.3518     73.54        94          65
# 2        Hermanus      ZA -34.4187   19.2345     66.27        84          94
# 3        Jiangyou      CN  31.7667  104.7167     38.12        70          92
# 4      Shellbrook      CA  53.2168 -106.4011      4.23        93         100
# 5        Olafsvik      IS  64.8945  -23.7142     25.34        70          68
# 6         Ushuaia      AR -54.8000  -68.3000     40.66        81          75
# 7         Tucurui      BR  -3.7661  -49.6725     73.17        90          94
# 8  Corpus Christi      US  27.8006  -97.3964     55.63        63          20
# 9         Mataura      NZ -46.1927  168.8643     80.40        42          18
#
#    Wind Speed Current Description
# 0        2.24                mist
# 1        5.01       broken clouds
# 2        4.32     overcast clouds
# 3        0.72     overcast clouds
# 4       13.78     overcast clouds
# 5       18.99       broken clouds
# 6       27.63          light rain
# 7        1.52     overcast clouds
# 8        9.22          few clouds
# 9        1.52          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
